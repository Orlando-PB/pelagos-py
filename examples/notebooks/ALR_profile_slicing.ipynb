# %% [markdown]
# # 1.0 Environment setup, module import

# %%
# add toolbox to src (THIS WILL NOT BE REQUIRED ONCE DEPLOYED)
from __future__ import annotations
import sys
from pathlib import Path
src_path = Path("../../src").resolve()

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from toolbox.steps.base_step import BaseStep, register_step
from toolbox.steps.custom import find_profiles_ALR as fpALR
import toolbox.utils.diagnostics as diag
import polars as pl
import matplotlib.pyplot as plt
import matplotlib as mpl
import tkinter as tk
import numpy as np
import re
import io
import matplotlib.pyplot as plt
# Out:
# [Discovery] Scanning for step modules in C:\Users\hanshil\Documents\GitHub\toolbox\src\toolbox\steps\custom
# [Discovery] Importing step module: toolbox.steps.custom.argo_qc
# [Discovery] Importing step module: toolbox.steps.custom.calibration
# [Discovery] Importing step module: toolbox.steps.custom.derive_ctd
# [Discovery] Failed to import toolbox.steps.custom.derive_ctd: No module named 'gsw'
# [Discovery] Importing step module: toolbox.steps.custom.export
# [Discovery] Importing step module: toolbox.steps.custom.find_profiles
# [Discovery] Importing step module: toolbox.steps.custom.find_profiles_ALR
# [Discovery] Importing step module: toolbox.steps.custom.gen_data
# [Discovery] Importing step module: toolbox.steps.custom.load_data
# [Discovery] Failed to import toolbox.steps.custom.load_data: No module named 'gsw'
# [Discovery] Importing step module: toolbox.steps.custom.variables.salinity
# [Discovery] Failed to import toolbox.steps.custom.variables.salinity: No module named 'gsw'
# [Discovery] Registered step: Argo QC
# [Discovery] Registered step: Data Export
# [Discovery] Registered step: Find Profiles
# [Discovery] Registered step: Generate Data

# %% [markdown]
# # 2.0 Data import
# Non-OG1 formatted ALR data is read in, formatted as a .log text file </br>
# For compatability, looking to format into this input format: </br>
# ```
#     Parameters
#     ----------
#     df : polars.DataFrame
#         Input dataframe containing time and depth measurements
#     gradient_thresholds : list
#         Two-element list [positive_threshold, negative_threshold] defining the vertical velocity
#         range (in meters/second) that is NOT considered part of a profile. typical values are around [0.02, -0.02]
#     filter_win_sizes : list, default= ['20s', '10s']
#         Window sizes for the compound filter applied to gradient calculations, in Polars duration format.
#         index 0 controls the rolling median window size and index 1 controls the rolling mean window size.
#     time_col : str, default='TIME'
#         Name of the column containing timestamp data
#     depth_col : str, default='DEPTH'
#         Name of the column containing depth measurements
# ```

# %% [markdown]
# ## 2.1 Data directories
# Locations where the ALR data is stored, building lists of all relevant files

# %%
# Folder containing CTD files
sci_ctd_dir = Path("../../test_data/ALR_4")
sci_ctd_file_type = '*.log'

# Get a list of all .log files
sci_ctd_data_files = [str(file.resolve()) for file in sci_ctd_dir.glob(sci_ctd_file_type)]

# Folder containing science_navigation files
sci_nav_dir = Path("../../test_data/ALR_4")
sci_nav_file_type = '*.csv'

# Get a list of all .log files
sci_nav_data_files = [str(file.resolve()) for file in sci_nav_dir.glob(sci_nav_file_type)]

# %% [markdown]
# ## 2.2 Loading in a single file set
# Parse a "ctd" and a "nav" file, combine them into a single Polars dataframe named 'combined'.

# %%
# Read in the CTD data
sci_ctd_file = sci_ctd_data_files[1]
sci_nav_file = sci_nav_data_files[1]

# Read in the nav data

with open(sci_ctd_file, "r") as f:
    lines = f.readlines()

# Identify start/end of each segment
segments = []
current_type = None
current_start = None

for i, line in enumerate(lines):
    if "4 Hz" in line:
        if current_type is not None:
            segments.append((current_type, current_start, i))
        current_type = "4hz"
        current_start = i + 1
    elif "1 Hz" in line:
        if current_type is not None:
            segments.append((current_type, current_start, i))
        current_type = "1hz"
        current_start = i + 1

if current_type is not None:
    segments.append((current_type, current_start, len(lines)))

parsed_segments = []

for seg_type, start, end in segments:
    raw = "".join(lines[start:end])

    if seg_type == "4hz":
        df = pl.read_csv(
            io.StringIO(raw),
            has_header=False,
            separator=",",
            new_columns=["Timestamp", "Pressure"],
            schema_overrides={
                "Timestamp": pl.Float64,
                "Pressure": pl.Float64,
            },
            null_values=["", "NaN", "S>"],
            ignore_errors=True
        )

    elif seg_type == "1hz":
        df = pl.read_csv(
            io.StringIO(raw),
            has_header=False,
            separator=",",
            new_columns=["Timestamp", "Conductivity", "Temperature", "Pressure", "Oxygen"],
            schema_overrides={
                "Timestamp": pl.Float64,
                "Conductivity": pl.Float64,
                "Temperature": pl.Float64,
                "Pressure": pl.Float64,
                "Oxygen": pl.Float64,
            },
            null_values=["", "NaN", "S>"],
            ignore_errors=True
        )

    parsed_segments.append(df)

# Combine all segments
all_data = pl.concat(parsed_segments, how="diagonal").sort("Timestamp")

# Read the nav data
sci_nav_data = pl.read_csv(
              sci_nav_file,
              schema_overrides={
             "timestamp": pl.Float64,
             "position_lat": pl.Float64,
             "position_lon": pl.Float64,
             "depth": pl.Float64,
             "roll": pl.Float64,
             "pitch": pl.Float64,
             "heading": pl.Float64,
             "altitude": pl.Float64}
)

# Merge two datasets
all_data = all_data.with_columns(pl.col("Timestamp").cast(pl.Float64))
sci_nav_data = sci_nav_data.rename({"timestamp": "Timestamp"}).with_columns(
    pl.col("Timestamp").cast(pl.Float64)
)

combined = all_data.join(
    sci_nav_data,
    on="Timestamp",
    how="full"   # union of both datasets
)

# Collapse Timestamp + Timestamp_right into a single column
if "Timestamp_right" in combined.columns:
    combined = combined.with_columns(
        pl.coalesce([pl.col("Timestamp"), pl.col("Timestamp_right")]).alias("Timestamp")
    ).drop("Timestamp_right")

# Sort chronologically
combined = combined.sort("Timestamp")

# Interpolate depth/pressure values over time gaps
combined = combined.with_columns(
    pl.col("Pressure").interpolate_by("Timestamp")
)

# %% [markdown]
# ## 2.3 All files
# Parse all files listed from section 2.1 into a single Polars dataframe labelled 'combined'.

# %%
import builtins  #newline17112025
VERBOSE_FILE_READ = False  #newline17112025
_original_print = print  #newline17112025
def _vprint(*args, **kwargs):  #newline17112025
    if VERBOSE_FILE_READ:  #newline17112025
        _original_print(*args, **kwargs)  #newline17112025
print = _vprint  #newline17112025

# --- Collect all CTD data ---
ctd_runs = []

for sci_ctd_file in sci_ctd_data_files:
    print(f"[CTD] Reading file: {sci_ctd_file}")  #newline17112025
    try:  #newline17112025
        with open(sci_ctd_file, "r") as f:
            lines = f.readlines()
    except Exception as e:  #newline17112025
        print(f"[CTD] ERROR opening {sci_ctd_file}: {e} — skipping")  #newline17112025
        continue  #newline17112025

    # Identify start/end of each segment
    segments = []
    current_type = None
    current_start = None
    for i, line in enumerate(lines):
        if "4 Hz" in line:
            if current_type is not None:
                segments.append((current_type, current_start, i))
            current_type = "4hz"
            current_start = i + 1
        elif "1 Hz" in line:
            if current_type is not None:
                segments.append((current_type, current_start, i))
            current_type = "1hz"
            current_start = i + 1
    if current_type is not None:
        segments.append((current_type, current_start, len(lines)))

    # Pre-clean: within 1hz segments, blank any lines that do NOT have exactly 5 comma-separated fields  #newline17112025
    for seg_idx_tmp, (seg_type_tmp, start_tmp, end_tmp) in enumerate(segments):  #newline17112025
        if seg_type_tmp == "1hz":  #newline17112025
            for j in range(start_tmp, end_tmp):  #newline17112025
                ln = lines[j].strip()  #newline17112025
                if not ln:  #newline17112025
                    continue  #newline17112025
                # Quick check first (4 commas -> 5 fields); then robust split length  #newline17112025
                if ln.count(",") != 4 or len(ln.split(",")) != 5:  #newline17112025
                    print(f"[CTD] Skipping non-5col line in 1hz at file_line={j}: {ln!r}")  #newline17112025
                    lines[j] = ""  #newline17112025

    print(f"[CTD] Detected segments ({len(segments)}): {segments}")  #newline17112025
    if not segments:  #newline17112025
        print(f"[CTD] WARNING {sci_ctd_file}: no 4 Hz or 1 Hz markers found — skipping")  #newline17112025
        continue  #newline17112025

    # Validate column counts for each segment before parsing
    invalid_file = False  #newline17112025
    for seg_idx, (seg_type, start, end) in enumerate(segments):  #newline17112025
        expected_cols = 2 if seg_type == "4hz" else 5  #newline17112025
        seg_lines = [ln.strip() for ln in lines[start:end] if ln.strip() != ""]  #newline17112025
        preview = seg_lines[:5]  #newline17112025
        print(f"[CTD] Validating seg#{seg_idx} type={seg_type} range=({start},{end}) lines={len(seg_lines)} expected_cols={expected_cols}")  #newline17112025
        for pi, pln in enumerate(preview):  #newline17112025
            print(f"        preview[{pi}] cols={len(pln.split(','))}: {pln!r}")  #newline17112025
        sampled = seg_lines[:50] if len(seg_lines) > 50 else seg_lines  #newline17112025
        mismatches = [ln for ln in sampled if len(ln.split(",")) != expected_cols]  #newline17112025
        if len(seg_lines) == 0:  #newline17112025
            print(f"[CTD] WARNING {sci_ctd_file}: empty {seg_type} segment — skipping file")  #newline17112025
            invalid_file = True  #newline17112025
            break  #newline17112025
        if mismatches:  #newline17112025
            print(f"[CTD] WARNING {sci_ctd_file}: seg#{seg_idx} ({seg_type}) incorrect column count (expected {expected_cols}). Showing first 5 mismatches:")  #newline17112025
            for mi, bad in enumerate(mismatches[:5]):  #newline17112025
                print(f"        mismatch[{mi}] cols={len(bad.split(','))}: {bad!r}")  #newline17112025
            invalid_file = True  #newline17112025
            break  #newline17112025
    if invalid_file:  #newline17112025
        continue  #newline17112025

    parsed_segments = []
    for seg_idx, (seg_type, start, end) in enumerate(segments):  #newline17112025
        raw = "".join(lines[start:end])
        raw_preview = "\n".join([ln for ln in raw.splitlines()[:5]])  #newline17112025
        print(f"[CTD] Parsing seg#{seg_idx} type={seg_type} chars={len(raw)} preview:\n{raw_preview}")  #newline17112025
        if seg_type == "4hz":
            try:  #newline17112025
                df = pl.read_csv(
                    io.StringIO(raw),
                    has_header=False,
                    separator=",",
                    new_columns=["Timestamp", "Pressure"],
                    schema_overrides={
                        "Timestamp": pl.Float64, 
                        "Pressure": pl.Float64,
                        },
                    null_values=["", "NaN", "S>"],
                    ignore_errors=True
                )
                print(f"[CTD] seg#{seg_idx} parsed OK: rows={df.height} cols={df.width} -> {df.columns}")  #newline17112025
            except Exception as e:  #newline17112025
                print(f"[CTD] ERROR parsing {sci_ctd_file} seg#{seg_idx} (4hz): {e} — skipping file")  #newline17112025
                parsed_segments = []  #newline17112025
                break  #newline17112025
        elif seg_type == "1hz":
            try:  #newline17112025
                # Rebuild raw from cleaned 'lines' slice ensuring only valid 5-col rows remain  #newline17112025
                raw = "".join([ln for ln in lines[start:end] if ln.strip()])  #newline17112025
                df = pl.read_csv(
                    io.StringIO(raw),
                    has_header=False,
                    separator=",",
                    new_columns=["Timestamp", "Conductivity", "Temperature", "Pressure", "Oxygen"],
                    schema_overrides={
                        "Timestamp": pl.Float64,
                        "Conductivity": pl.Float64,
                        "Temperature": pl.Float64,
                        "Pressure": pl.Float64,
                        "Oxygen": pl.Float64,
                    },
                    null_values=["", "NaN", "S>"],
                    ignore_errors=True
                )
                print(f"[CTD] seg#{seg_idx} parsed OK: rows={df.height} cols={df.width} -> {df.columns}")  #newline17112025
            except Exception as e:  #newline17112025
                print(f"[CTD] ERROR parsing {sci_ctd_file} seg#{seg_idx} (1hz): {e} — skipping file")  #newline17112025
                parsed_segments = []  #newline17112025
                break  #newline17112025
        parsed_segments.append(df)

    if len(parsed_segments) == 0:  #newline17112025
        continue  #newline17112025

    run_df = pl.concat(parsed_segments, how="diagonal").sort("Timestamp")
    run_df = run_df.with_columns(pl.lit(sci_ctd_file).alias("source_ctd"))
    print(f"[CTD] OK: {sci_ctd_file} parsed with {run_df.height} rows")  #newline17112025
    ctd_runs.append(run_df)

all_ctd = pl.concat(ctd_runs, how="diagonal").sort("Timestamp")

# --- Collect all NAV data ---
nav_runs = []
for sci_nav_file in sci_nav_data_files:
    print(f"[NAV] Reading file: {sci_nav_file}")  #newline17112025
    try:  #newline17112025
        df = pl.read_csv(
            sci_nav_file,
            schema_overrides={
                "timestamp": pl.Float64,
                "position_lat": pl.Float64,
                "position_lon": pl.Float64,
                "depth": pl.Float64,
                "roll": pl.Float64,
                "pitch": pl.Float64,
                "heading": pl.Float64,
                "altitude": pl.Float64
            }
        )
    except Exception as e:  #newline17112025
        print(f"[NAV] ERROR opening/parsing {sci_nav_file}: {e} — skipping")  #newline17112025
        continue  #newline17112025

    print(f"[NAV] Columns: {list(df.columns)} rows={df.height}")  #newline17112025
    required_cols = {"timestamp","position_lat","position_lon","depth","roll","pitch","heading","altitude"}  #newline17112025
    missing = required_cols.difference(set(df.columns))  #newline17112025
    if missing:  #newline17112025
        print(f"[NAV] WARNING {sci_nav_file}: missing required columns: {sorted(missing)} — skipping")  #newline17112025
        continue  #newline17112025

    df = df.rename({"timestamp": "Timestamp"})
    df = df.with_columns(
        pl.col("Timestamp").cast(pl.Float64),
        pl.lit(sci_nav_file).alias("source_nav")
    )
    print(f"[NAV] OK: {sci_nav_file} parsed with {df.height} rows")  #newline17112025
    nav_runs.append(df)

all_nav = pl.concat(nav_runs, how="diagonal").sort("Timestamp")

# --- Merge CTD + NAV across all files ---
big_df = all_ctd.join(all_nav, on="Timestamp", how="full")

# Collapse Timestamp_right if it appears
if "Timestamp_right" in big_df.columns:
    big_df = big_df.with_columns(
        pl.coalesce([pl.col("Timestamp"), pl.col("Timestamp_right")]).alias("Timestamp")
    ).drop("Timestamp_right")

# Sort chronologically
big_df = big_df.sort("Timestamp")

# Interpolate Pressure if possible
if big_df["Pressure"].drop_nulls().len() > 0:
    big_df = big_df.with_columns(
        pl.col("Pressure").interpolate_by("Timestamp")
    )

# QC: drop rows where BOTH Pressure and pitch are null
big_df = big_df.filter(
    ~(pl.col("Pressure").is_null() & pl.col("pitch").is_null())
)

# Add an index column to big_df for tracking
big_df = big_df.with_row_index(name="row_id")

# %% [markdown]
# ### 2.3.1 Already formatted data files (e.g. TechOceans Deployment)

# %%
# ── 2.3.1  Pre-formatted CSV → big_df ──────────────────────────────────────────
# Replace the path below with the location of your formatted CSV file.
preformatted_file = Path("C:\\Users\\hanshil\\Documents\\GitHub\\toolbox\\test_data\\ALR_TechOceans\\ctd_with_alr_position-ODV 1.csv")

# --- Read ---
big_df = pl.read_csv(
    preformatted_file,
    separator=",",
    schema_overrides={
        "Date":                   pl.Utf8,
        "Latitudedegrees_north":  pl.Float64,
        "Longitudedegrees_east":  pl.Float64,
        "Depthm":                 pl.Float64,
        "roll":                   pl.Float64,
        "pitch":                  pl.Float64,
        "heading":                pl.Float64,
        "ConductivitymScm":       pl.Float64,
        "TemperatureC":           pl.Float64,
        "pbar":                   pl.Float64,
        "oxygen_1Hz":             pl.Float64,
        "SP":                     pl.Float64,
        "Oxygen [mL/L]":          pl.Float64,
        "Oxsol (T,S)":            pl.Float64,
        "Oxygen (umol/L)":        pl.Float64,
    },
    null_values=["", "NaN"],
)

# --- Column mapping → names expected by sections 2.4 onwards ---
big_df = big_df.rename({
    "Latitudedegrees_north": "position_lat",
    "Longitudedegrees_east": "position_lon",
    "Depthm":                "depth",
    "ConductivitymScm":      "Conductivity",
    "TemperatureC":          "Temperature",
    "pbar":                  "Pressure",
    "oxygen_1Hz":            "Oxygen",
})

# --- Convert ISO-8601 timestamp → Unix epoch seconds (Float64) ---
big_df = big_df.with_columns(
    pl.col("Date")
      .str.to_datetime(format="%Y-%m-%dT%H:%M:%SZ", time_unit="us")
      .dt.epoch(time_unit="s")
      .cast(pl.Float64)
      .alias("Timestamp")
).drop("Date")

# --- altitude is not present in this file; add null column for schema parity ---
big_df = big_df.with_columns(
    pl.lit(None).cast(pl.Float64).alias("altitude")
)

# --- Interpolate Pressure over any gaps (mirrors raw pipeline behaviour) ---
if big_df["Pressure"].drop_nulls().len() > 0:
    big_df = big_df.with_columns(
        pl.col("Pressure").interpolate_by("Timestamp")
    )

# --- QC: drop rows where BOTH Pressure and pitch are null ---
big_df = big_df.filter(
    ~(pl.col("Pressure").is_null() & pl.col("pitch").is_null())
)

# --- Row index (mirrors raw pipeline) ---
big_df = big_df.with_row_index(name="row_id")

print(f"big_df ready: {big_df.height} rows, {big_df.width} columns")
print(big_df.columns)
# Out:
# big_df ready: 544851 rows, 17 columns
# ['row_id', 'position_lat', 'position_lon', 'depth', 'roll', 'pitch', 'heading', 'Conductivity', 'Temperature', 'Pressure', 'Oxygen', 'SP', 'Oxygen [mL/L]', 'Oxsol (T,S)', 'Oxygen (umol/L)', 'Timestamp', 'altitude']

# %% [markdown]
# ## 2.4 Inspecting the data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Increase font sizes globally
plt.rcParams.update({
    "font.size": 18,
    "axes.labelsize": 18,
    "xtick.labelsize": 18,
    "ytick.labelsize": 18,
})

# Convert TIME column
df_plot = big_df.with_columns(
    (pl.col("Timestamp") * 1e9).cast(pl.Datetime("ns")).alias("TIME")
)

# Extract numpy arrays
time_vals = df_plot["TIME"].to_numpy()
pressure_vals = df_plot["Pressure"].to_numpy()
pitch_vals = df_plot["pitch"].to_numpy()

#time_vals_x_axis_min = np.argmax(time_vals>np.datetime64('2024-07-24'))
#time_vals_x_axis_max = np.argmin(time_vals<np.datetime64('2024-07-26'))

# Plotting
fig, axs = plt.subplots(1, 1, figsize=(18, 8), sharex=True)

# Pressure
axs.plot(time_vals, pressure_vals,
         marker=".", markersize=1, ls="", c="tab:blue")
axs.set_ylabel("Pressure (dbar)")
axs.invert_yaxis()

#axs.set_xlim(time_vals[time_vals_x_axis_min], time_vals[time_vals_x_axis_max])


plt.tight_layout()
plt.show()

# %%
time_vals_x_axis_min = np.argmax(time_vals>np.datetime64('2024-07-18'))
time_vals_x_axis_max = np.argmin(time_vals<np.datetime64('2024-07-21'))

# %% [markdown]
# # 3.0 Profile analysis
# Using the output of either section 2.2 or 2.3 for profile analysis using the 'find_profiles_ALR.py' script and it's contained functions.

# %% [markdown]
# ## 3.1 Running 'find_profiles_ALR.py'
# Take above ALR data and output into a profiled format

# %%
# --- Profiling analysis ---

import importlib
importlib.reload(fpALR)

gradient_thresholds = [0.05, -0.05]
cust_gradient_thresholds = [0.005, -0.005]
custom_column = 'pitch'

df_to_use = big_df

# Rename columns to what find_profiles expects
df = df_to_use.rename({
    "Timestamp": "TIME",
    "Pressure": "DEPTH"   # treat pressure as depth for profiling
})

# Convert TIME (epoch seconds float) → Datetime[ns]
df = df.with_columns(
    (pl.col("TIME") * 1e9).cast(pl.Datetime("ns")).alias("TIME")
)

# Run profile detection with a custom column
profiles_df = fpALR.find_profiles(
    df,
    gradient_thresholds=gradient_thresholds,
    filter_win_sizes=["30s", "20s"],
    time_col="TIME",
    depth_col="DEPTH",
    cust_col=custom_column,
    cust_gradient_thresholds=cust_gradient_thresholds,
    transect_duration='5m',
    transect_depth_range=[10,20,30],
    transect_depth_bottom_limits=[20,50],
    profile_duration='1m',
    strict_profiles=False,
    use_only_pit_vel=False,
    back_fill_mod=1,
    backfill_segments=True,
    force_split_up_down_casts=False,
)

profiles_df = profiles_df.drop_nans('is_profile')

# %%
# Split profiles vs not profiles
profiles = profiles_df.drop_nans().filter(pl.col("is_profile").cast(pl.Boolean))
not_profiles = profiles_df.drop_nans().filter(pl.col("is_profile").cast(pl.Boolean).not_())
transects = profiles_df.drop_nans().filter(pl.col("is_transect").cast(pl.Boolean))
not_transects = profiles_df.drop_nans().filter(pl.col("is_transect").cast(pl.Boolean).not_())

# === Plotting ===
import matplotlib as mpl
#mpl.use('tkagg')
fig, axs = plt.subplots(5, 1, figsize=(18, 10), height_ratios=[3, 3, 1, 3, 3], sharex=True)

axs[0].set(xlabel="Time", ylabel="Interpolated Depth")
axs[1].set(xlabel="Time", ylabel="Vertical Velocity")
axs[2].set(xlabel="Time", ylabel="Profile Number")
axs[3].set(xlabel="Time", ylabel=custom_column)   # <<< custom col
axs[4].set(xlabel="Time", ylabel=custom_column)   # <<< custom col

# Profile vs not profile (depth + velocity)
for data, col, label in zip([profiles, not_profiles, transects], 
                            ["tab:blue", "tab:red", "tab:orange"], 
                            ["Profile", "Not Profile", "Transect"]):
    axs[0].plot(data["TIME"].to_numpy(), -data["INTERP_DEPTH"].to_numpy(),
                marker=".", markersize=1, ls="", c=col, label=label)
    axs[1].plot(data["TIME"].to_numpy(), data["smooth_grad"].to_numpy(),
                marker=".", markersize=1, ls="", c=col, label=label)

# Raw gradients + thresholds
axs[1].plot(profiles_df["TIME"].to_numpy(), profiles_df["grad"].to_numpy(),
            c="k", alpha=0.1, label="Raw Velocity")
for val, label in zip(gradient_thresholds, ["Gradient Thresholds", None]):
    axs[1].axhline(val, ls="--", color="gray", label=label)

# Profile numbers
axs[2].plot(profiles_df["TIME"].to_numpy(), profiles_df["profile_num"].to_numpy(), c="gray")
axs[2].plot(profiles_df["TIME"].to_numpy(), profiles_df["profile_num_new"].to_numpy(), c="red")

# Custom column (pitch)
if custom_column in profiles_df.columns:
    axs[3].plot(profiles_df["TIME"].to_numpy(),
                profiles_df[custom_column].to_numpy(),
                c="purple", marker=".", markersize=1, ls="", label=custom_column)
    axs[3].legend(loc="right")

# Custom column (pitch)
if custom_column in profiles_df.columns:
    axs[4].plot(profiles_df["TIME"].to_numpy(),
                -profiles_df['smooth_INTERP_pitch'].to_numpy()*profiles_df['smooth_grad'].to_numpy(),
                c="purple", marker=".", markersize=1, ls="", label=custom_column)
    axs[4].legend(loc="right")
    axs[4].set_ylim([0, 0.05])
for val, label in zip(cust_gradient_thresholds, ["Gradient Thresholds", None]):
    axs[4].axhline(val, ls="--", color="gray", label=label)

for ax in axs[:2]:
    ax.legend(loc="upper right")

plt.tight_layout()
plt.show(block=True)

# %% [markdown]
# ## 3.2. Plotting just vertical velocities

# %%
# === Plotting (vertical velocity only, fixed axis) ===
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# Set global font properties
plt.rcParams.update({
    "font.family": "Arial",
    "font.size": 16,
    "axes.labelsize": 16,
    "xtick.labelsize": 16,
    "ytick.labelsize": 16,
    "legend.fontsize": 16
})

fig, axs = plt.subplots(1, 1, figsize=(18, 3), sharex=True)

axs.set_xlabel("Time")
axs.set_ylabel("Vertical Velocity (m/s)")
axs.set_ylim([-0.5, 0.5])   # <<< fixed axis limits (±0.5)

# Plot ONLY vertical velocity for profile, non-profile, transect
for data, col, label in zip(
        [profiles, not_profiles, transects],
        ["tab:blue", "tab:red", "tab:orange"],
        ["Profile", "Not Profile", "Transect"]):

    axs.plot(
        data["TIME"].to_numpy(),
        data["smooth_grad"].to_numpy(),
        marker=".", markersize=1, ls="", c=col, label=label
    )

axs.legend(loc="upper right")

plt.tight_layout()
plt.show(block=True)

# %% [markdown]
# # 4.0 Export to netCDF

# %%
plt.close()

# %%
# Ensure both sides have matching TIME column format
df = df.with_columns(pl.col("TIME").cast(pl.Datetime("ns")))
profile_annotations = profiles_df.with_columns(pl.col("TIME").cast(pl.Datetime("ns")))

big_df_with_profiles = df.join(
    profile_annotations,
    on=["TIME", "DEPTH"],
    how="left"
)

big_df_with_profiles = big_df_with_profiles.filter(
    pl.col("TIME").is_not_null()
)

# %%
mpl.use('tkagg')
# Convert TIME column
df_plot = big_df_with_profiles

xx_val1 = "Temperature"
xx_val2 = "position_lat"

# Extract numpy arrays
time_vals = df_plot["TIME"].to_numpy()
pressure_vals = df_plot["DEPTH"].to_numpy()
xx_val1_vals = df_plot[xx_val1].to_numpy()
xx_val2_vals = df_plot[xx_val2].to_numpy()

# Plotting (2 panels, shared x-axis)
fig, axs = plt.subplots(2, 1, figsize=(18, 8), sharex=True)

# Pressure (treat as depth)
axs[0].plot(time_vals, xx_val1_vals,
            marker=".", markersize=1, ls="", c="tab:blue")
axs[0].set(ylabel=xx_val1)
axs[0].invert_yaxis()

# Pitch
axs[1].plot(time_vals, xx_val2_vals,
            marker=".", markersize=1, ls="", c="purple")
axs[1].set(xlabel="Time", ylabel=xx_val2)

plt.tight_layout()
plt.show(block=True)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import numpy as np
import polars as pl

mpl.use("tkagg")

# === Helper: Truncate colormap ===
def truncate_cmap(name, minval=0.25, maxval=1.0, n=256):
    cmap = mpl.colormaps[name]
    return mpl.colors.LinearSegmentedColormap.from_list(
        f"trunc({name},{minval},{maxval})", cmap(np.linspace(minval, maxval, n))
    )

def to_pytime(series: pl.Series):
    """Convert Polars datetime column to numpy array of Python datetimes."""
    return np.array(series.to_list())

# === Extract data ===
time_vals = to_pytime(big_df_with_profiles["TIME"])
pressure_vals = big_df_with_profiles["DEPTH"].to_numpy()
pitch_vals = big_df_with_profiles["pitch"].to_numpy()
profile_nums = big_df_with_profiles["profile_num"].to_numpy()
transect_nums = big_df_with_profiles["transect_num"].to_numpy()
profile_nums_new = big_df_with_profiles["profile_num_new"].to_numpy()

# === Figure setup ===
fig, axs = plt.subplots(
    3, 1, figsize=(18, 12),
    height_ratios=[3, 3, 3],
    sharex=True
)

# === Profile plots ===
unique_profiles = np.unique(profile_nums[profile_nums >= 0])
unique_profiles_new = np.unique(profile_nums_new[profile_nums_new >= 0])

cmap_orig = truncate_cmap("Blues")
norm_orig = Normalize(vmin=unique_profiles.min(), vmax=unique_profiles.max())
cmap_new = truncate_cmap("Reds")
norm_new = Normalize(vmin=unique_profiles_new.min(), vmax=unique_profiles_new.max())

# Original profiles (blue)
for pid in unique_profiles:
    mask = profile_nums == pid
    axs[0].plot(time_vals[mask], pressure_vals[mask],
                color=cmap_orig(norm_orig(pid)), lw=2, alpha=0.9)

# Filtered profiles (red)
for pid in unique_profiles_new:
    mask = profile_nums_new == pid
    axs[0].plot(time_vals[mask], pressure_vals[mask],
                color=cmap_new(norm_new(pid)), lw=1.5, alpha=0.9)

axs[0].invert_yaxis()
axs[0].set(ylabel="Pressure (dbar)", title="Profiles (Original vs Filtered)")

# Colorbars (inset)
cax1 = inset_axes(axs[0], width="35%", height="4%", loc="lower left", borderpad=2)
fig.colorbar(ScalarMappable(norm=norm_orig, cmap=cmap_orig),
             cax=cax1, orientation="horizontal", label="Original profile #")
cax2 = inset_axes(axs[0], width="35%", height="4%", loc="lower right", borderpad=2)
fig.colorbar(ScalarMappable(norm=norm_new, cmap=cmap_new),
             cax=cax2, orientation="horizontal", label="Filtered profile #")

# === Raw pressure ===
axs[1].plot(time_vals, pressure_vals, ".", markersize=1, c="tab:blue")
axs[1].invert_yaxis()
axs[1].set(ylabel="Pressure (dbar)")

# === Transects ===
unique_transects = np.unique(transect_nums[transect_nums >= 0])
cmap_transects = truncate_cmap("Greens")
norm_transects = Normalize(vmin=unique_transects.min(), vmax=unique_transects.max())

for tid in unique_transects:
    mask = transect_nums == tid
    axs[2].plot(time_vals[mask], pressure_vals[mask],
                color=cmap_transects(norm_transects(tid)), lw=1)

axs[2].invert_yaxis()
axs[2].set(ylabel="Pressure (dbar)", title="Transects")

# Colorbar inset
cax_tr = inset_axes(axs[2], width="50%", height="4%", loc="lower center", borderpad=1.5)
fig.colorbar(ScalarMappable(norm=norm_transects, cmap=cmap_transects),
             cax=cax_tr, orientation="horizontal", label="Transect number")


fig.tight_layout()
plt.show(block=True)
# Out:
# C:\Users\hanshil\AppData\Local\Temp\ipykernel_39532\575261458.py:93: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# Good evening GPT, hope you're doing well!
#
# I'd like to convert a dataframe in Python into a series of distinctly labelled netCDF files.
#
# I have the following polars dataframe:
#
# big_df_with_profiles
#
# With the following characteristics:
#
# big_df_with_profiles.head(10)
#
#
# <div><style>
# .dataframe > thead > tr,
# .dataframe > tbody > tr {
#   text-align: right;
#   white-space: pre-wrap;
# }
# </style>
# <small>shape: (10, 37)</small><table border="1" class="dataframe"><thead><tr><th>row_id</th><th>TIME</th><th>DEPTH</th><th>Conductivity</th><th>Temperature</th><th>Oxygen</th><th>source_ctd</th><th>position_lat</th><th>position_lon</th><th>depth</th><th>roll</th><th>pitch</th><th>heading</th><th>altitude</th><th>source_nav</th><th>pitch_right</th><th>INTERP_DEPTH</th><th>INTERP_pitch</th><th>dt</th><th>dz</th><th>dC</th><th>grad</th><th>dC/dt</th><th>smooth_grad</th><th>smooth_INTERP_pitch</th><th>smooth_dC/dt</th><th>grad_profile</th><th>pitch_profile</th><th>is_profile</th><th>profile_num</th><th>profile_num_new</th><th>roll_min_depth</th><th>roll_max_depth</th><th>depth_stable</th><th>pitch_flat</th><th>is_transect</th><th>transect_num</th></tr><tr><td>u32</td><td>datetime[ns]</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>str</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>str</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td></tr></thead><tbody><tr><td>0</td><td>2024-06-09 09:29:31.578629888</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>63.443264</td><td>-20.26803</td><td>0.155416</td><td>0.0</td><td>0.0</td><td>0.0</td><td>184.259995</td><td>&quot;C:\Users\hanshil\Documents\Git…</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1</td><td>2024-06-09 09:29:31.617340160</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>63.443264</td><td>-20.26803</td><td>0.155416</td><td>0.0</td><td>0.0</td><td>0.0</td><td>193.979996</td><td>&quot;C:\Users\hanshil\Documents\Git…</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2</td><td>2024-06-09 09:29:32.668800</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>63.443264</td><td>-20.26803</td><td>0.143438</td><td>0.0</td><td>0.0</td><td>0.0</td><td>193.979996</td><td>&quot;C:\Users\hanshil\Documents\Git…</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>3</td><td>2024-06-09 09:29:33.734360064</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>63.443264</td><td>-20.26803</td><td>0.146394</td><td>0.0</td><td>0.0</td><td>0.0</td><td>193.979996</td><td>&quot;C:\Users\hanshil\Documents\Git…</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>4</td><td>2024-06-09 09:29:34.640339968</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>63.443264</td><td>-20.26803</td><td>0.152938</td><td>0.0</td><td>0.0</td><td>0.0</td><td>188.335007</td><td>&quot;C:\Users\hanshil\Documents\Git…</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>5</td><td>2024-06-09 09:29:35.654840064</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>63.443264</td><td>-20.26803</td><td>0.151805</td><td>0.0</td><td>0.0</td><td>0.0</td><td>192.350006</td><td>&quot;C:\Users\hanshil\Documents\Git…</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>6</td><td>2024-06-09 09:29:36.628560128</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>63.443264</td><td>-20.26803</td><td>0.142937</td><td>-0.015278</td><td>0.00218</td><td>0.745214</td><td>192.350006</td><td>&quot;C:\Users\hanshil\Documents\Git…</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>7</td><td>2024-06-09 09:29:37.624020224</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>63.443264</td><td>-20.26803</td><td>0.135844</td><td>-0.015348</td><td>0.002386</td><td>0.745505</td><td>189.604996</td><td>&quot;C:\Users\hanshil\Documents\Git…</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8</td><td>2024-06-09 09:29:38.636819968</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>63.443264</td><td>-20.26803</td><td>0.136139</td><td>-0.015052</td><td>0.0023</td><td>0.744832</td><td>189.604996</td><td>&quot;C:\Users\hanshil\Documents\Git…</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>9</td><td>2024-06-09 09:29:39.611560192</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>63.443264</td><td>-20.26803</td><td>0.13936</td><td>-0.015037</td><td>0.002175</td><td>0.746551</td><td>192.714996</td><td>&quot;C:\Users\hanshil\Documents\Git…</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>
#
# big_df_with_profiles.shape
# (10656537, 37)
#
# I don't need to bring across the 'source_ctd' elements. I'd like to pick which columns we bring across eventually, but for now we just need to ensure each netCDF contains:
# Depth
# Id like the netCDF to be structured such that we have a netCDF file for each unique profile ID and each unique transect ID.
#
# I'd like to iterate through the files with the following naming convention logic, with a base of:
#
# ALRXXX_XXXX_XXXX_XXXX_aXXXX
#
# Where the first portion:
#
# Is the serial number of the ALR (this should be user defined and fixed for a given export 'chunk' of files)
# e.g. ALR004
#
# The second:
#
# Is the 'unique_ID' of the file. This should increase by 1 for each new file.
# e.g. 0001
#
# The third:
# This is the 'segment_ID'. Segments are periods of time between two subsequent dives (in this case the first point defining a downcast, with downcast defined as a profile of increasing depth) from the surface (here defined as anything <5m depth).
# e.g. 0001
#
# The fourth:
# event_type_ID and unique_event_type_ID. A letter and number corresponding to a specific type of profile, whether it is a downcast (depth values increase), an upcast (depth values decrease), a transect (already labelled in our files), or a transect at the surface (depth values for the transect are on average shallower than 5m, this 5m threshold should be user defined).
# e.g. s0001
#
# So a complete file for the first, surface transect of a deployment (a deployment being this large dataframe), would be:
# ALR004_0001_0001_s0001
#
# The eighty-second sample from the same deployment (dataframe), a downcast in the twenty-ninth segment (peroids between two dowcasts from the surface), which is the twentieth downcast, would be:
# ALR004_0082_0029_d0020

# %%
# -*- coding: utf-8 -*-
"""
Export ALR profiles, transects, and 'other' (x) sections from a Polars DataFrame to NetCDF files.

Changes vs. previous version:
- Filenames now include YYYYMMDD (UTC) of the event's first datapoint:  ALR004_20240401_0082_0029_d0020.nc
- All data are exported: in addition to profiles (d/u) and transects (t/s), we create one 'x' event per segment
  for rows that are neither profile nor transect. Segment '0000' is everything prior to the first surface-origin
  downcast; subsequent segments increment at each such downcast start.

Requirements:
    pip install polars xarray netCDF4 numpy pandas
"""

# -*- coding: utf-8 -*-
import os
from typing import Optional, List, Dict, Tuple
import numpy as np
import pandas as pd
import polars as pl
import xarray as xr
from bisect import bisect_right


def _ensure_dir(path: str) -> None:
    os.makedirs(path, exist_ok=True)


def _first_last_depth_for_profile(g: pl.DataFrame) -> Tuple[Optional[float], Optional[float]]:
    g_sorted = g.sort("TIME")
    if "DEPTH" in g.columns:
        d = g_sorted.get_column("DEPTH").drop_nulls()
        if d.len() > 0:
            return float(d[0]), float(d[-1])
    if "depth" in g.columns:
        d = g_sorted.get_column("depth").drop_nulls()
        if d.len() > 0:
            return float(d[0]), float(d[-1])
    return None, None


def _mean_depth(g: pl.DataFrame) -> Optional[float]:
    if "DEPTH" in g.columns:
        m = g.select(pl.col("DEPTH")).mean().item()
        if m is not None:
            return float(m)
    if "depth" in g.columns:
        m = g.select(pl.col("depth")).mean().item()
        if m is not None:
            return float(m)
    return None


def _event_type_for_profile(g: pl.DataFrame) -> str:
    first_d, last_d = _first_last_depth_for_profile(g)
    if first_d is None or last_d is None:
        return "d"
    if first_d < last_d:
        return "d"
    elif first_d > last_d:
        return "u"
    else:
        return "d"


def _event_type_for_transect(g: pl.DataFrame, surface_thresh: float) -> str:
    m = _mean_depth(g)
    if m is None:
        return "t"
    return "s" if m < surface_thresh else "t"


def _dataset_from_group(g: pl.DataFrame) -> xr.Dataset:
    rename_map = {
        "DEPTH": "DEPTH_SCI",
        "depth": "DEPTH_ENG",
        "INTERP_DEPTH": "DEPTH_SCI_INTERP",
        "position_lat": "LAT",
        "position_lon": "LON",
        "TIME": "TIME",
        "Temperature": "TEMPERATURE",
        "Conductivity": "CONDUCTIVITY",
        "Oxygen": "OXYGEN",
        "pitch": "PITCH_ENG",
        "roll": "ROLL_ENG",
    }
    keep_cols = [c for c in rename_map.keys() if c in g.columns]
    if "TIME" not in keep_cols:
        raise ValueError("Required column 'TIME' missing from group.")

    g2 = (
        g.sort("TIME")
         .select(keep_cols)
         .rename({k: v for k, v in rename_map.items() if k in keep_cols})
    )

    pdf = g2.to_pandas()
    pdf["TIME"] = pd.to_datetime(pdf["TIME"], utc=True, errors="coerce")
    pdf = pdf.dropna(subset=["TIME"])

    epoch = np.datetime64("1970-01-01T00:00:00")
    time_seconds = (pdf["TIME"].values.astype("datetime64[ns]") - epoch) / np.timedelta64(1, "s")

    ds = xr.Dataset(
        data_vars={
            k: (("TIME",), pdf[k].to_numpy())
            for k in ["DEPTH_SCI", "DEPTH_ENG", "DEPTH_SCI_INTERP", "LAT", "LON","Temperature","Conductivity","Oxygen","pitch","roll"]
            if k in pdf.columns
        },
        coords={"TIME": time_seconds},
    )

    ds["TIME"].attrs.update({
        "units": "seconds since 1970-01-01 00:00:00 UTC",
        "long_name": "time",
        "standard_name": "time",
    })

    ds.attrs.update({
        "Conventions": "CF-1.9",
        "title": "ALR profile/transect/other export",
        "institution": "NOCS",
        "source": "Polars→xarray export",
        "history": "Created by export_alr_netcdf()",
        "author": "hans.hilder@noc.ac.uk",
    })
    return ds


def export_alr_netcdf(
    df: pl.DataFrame,
    *,
    alr_serial: str = "ALR000",
    surface_thresh: float = 5.0,
    output_dir: str = "output_ALR000_netCDF",
    max_files: Optional[int] = 5,
) -> List[str]:
    """
    Exports per-profile (d/u), per-transect (t/s), and per-'other' contiguous run (x) NetCDF files.

    Filename:
        {alr_serial}_{YYYYMMDD}_{unique_id:04d}_{segment_id:04d}_{etype}{etype_idx:04d}.nc

    Segment ID:
        0000 for anything before the first downcast that begins shallower than `surface_thresh`.
        Increments by 1 at each such downcast start thereafter.
    """
    _ensure_dir(output_dir)

    must_have = ["TIME", "position_lat", "position_lon"]
    missing_req = [c for c in must_have if c not in df.columns]
    if missing_req:
        raise ValueError(f"Missing required columns: {missing_req}")

    maybe_cols = [
        "DEPTH", "depth", "INTERP_DEPTH",
        "profile_num_new", "transect_num",
        "is_profile", "is_transect",
        "Temperature","Conductivity","Oxygen",
        "pitch","roll",
    ]
    subset_cols = list(dict.fromkeys(must_have + [c for c in maybe_cols if c in df.columns]))

    # Sort and index early so we can split 'x' by contiguous runs.
    sdf = (
        df.select(subset_cols)
          .with_columns(pl.col("TIME").cast(pl.Datetime).alias("TIME"))
          .sort("TIME")
          .with_row_count("orig_idx")
    )

    # ---------- Build profile groups & collect downcast starts ----------
    profile_groups = []
    downcast_start_times_utc: List[pd.Timestamp] = []

    if "is_profile" in sdf.columns and "profile_num_new" in sdf.columns:
        prof_df = sdf.filter(pl.col("is_profile") == 1).drop_nulls(["profile_num_new"])
        if prof_df.height > 0:
            for key, g in prof_df.group_by("profile_num_new", maintain_order=False):
                start_time = pd.to_datetime(g.select(pl.col("TIME").min()).item(), utc=True)
                etype = _event_type_for_profile(g)
                profile_groups.append({
                    "kind": "profile",
                    "key": int(key[0]) if isinstance(key, tuple) else int(key),
                    "start_time": start_time,
                    "etype": etype,
                    "group": g.drop("orig_idx"),
                })
                if etype == "d":
                    first_d, _ = _first_last_depth_for_profile(g)
                    if first_d is not None and first_d < surface_thresh:
                        downcast_start_times_utc.append(start_time)

    # Keep these sorted for bisect-based segment lookup
    downcast_start_times_utc.sort()

    # ---------- Build transect groups ----------
    transect_groups = []
    if "is_transect" in sdf.columns and "transect_num" in sdf.columns:
        tran_df = sdf.filter(pl.col("is_transect") == 1).drop_nulls(["transect_num"])
        if tran_df.height > 0:
            for key, g in tran_df.group_by("transect_num", maintain_order=False):
                start_time = pd.to_datetime(g.select(pl.col("TIME").min()).item(), utc=True)
                etype = _event_type_for_transect(g, surface_thresh=surface_thresh)
                transect_groups.append({
                    "kind": "transect",
                    "key": int(key[0]) if isinstance(key, tuple) else int(key),
                    "start_time": start_time,
                    "etype": etype,
                    "group": g.drop("orig_idx"),
                })

    # ---------- Compute per-row segment_id (join_asof on downcast starts) ----------
    if downcast_start_times_utc:
        # Make naive-UTC datetimes for Polars join
        seg_starts = [pd.Timestamp(t).tz_convert("UTC").tz_localize(None).to_pydatetime()
                      for t in downcast_start_times_utc]
        seg_df = pl.DataFrame({"SEG_START": seg_starts}).with_row_count("segment_id", offset=1)
        sdf_with_seg = sdf.join_asof(
            seg_df.sort("SEG_START"),
            left_on="TIME", right_on="SEG_START",
            strategy="backward"
        ).with_columns(pl.col("segment_id").fill_null(0))
    else:
        sdf_with_seg = sdf.with_columns(pl.lit(0).alias("segment_id"))

    # ---------- Build 'x' groups: contiguous runs within each segment ----------
    # Rows that are neither profile nor transect
    not_flagged = (
        (pl.col("is_profile") != 1) & (pl.col("is_transect") != 1)
        if "is_profile" in sdf_with_seg.columns and "is_transect" in sdf_with_seg.columns
        else pl.lit(True)
    )

    other_df = (
        sdf_with_seg
        .filter(not_flagged)
        .select(["TIME", "position_lat", "position_lon", "DEPTH", "depth",
                 "INTERP_DEPTH", "segment_id", "orig_idx","Temperature","Conductivity","Oxygen","pitch","roll"])
        .sort(["segment_id", "orig_idx"])
        .with_columns([
            # new run when segment changes OR original index is not consecutive
            (
                (pl.col("segment_id").diff().fill_null(0) != 0)
                | (pl.col("orig_idx").diff() != 1)
            ).fill_null(True).cast(pl.Int8).alias("new_run")
        ])
        .with_columns([
            pl.col("new_run").cum_sum().alias("x_run_id")
        ])
    )

    x_groups = []
    if other_df.height > 0:
        for (seg_id, run_id), g in other_df.group_by(["segment_id", "x_run_id"], maintain_order=True):
            start_time = pd.to_datetime(g.select(pl.col("TIME").min()).item(), utc=True)
            x_groups.append({
                "kind": "other",
                "key": (int(seg_id), int(run_id)),
                "start_time": start_time,
                "etype": "x",
                "group": g.drop(["segment_id", "orig_idx", "new_run", "x_run_id"]),
                "segment_id_override": int(seg_id),
            })

    # ---------- Merge & sort all events ----------
    events = profile_groups + transect_groups + x_groups
    if not events:
        return []

    events.sort(key=lambda e: e["start_time"])

    # ---------- Write files ----------
    unique_id = 0
    per_type_counts: Dict[str, int] = {"d": 0, "u": 0, "t": 0, "s": 0, "x": 0}
    written: List[str] = []

    for ev in events:
        if max_files is not None and len(written) >= max_files:
            break

        etype = ev["etype"]

        # Segment ID lookup: count how many downcast starts <= this event's start_time
        seg_id_for_file = ev.get(
            "segment_id_override",
            bisect_right(downcast_start_times_utc, ev["start_time"])
        )

        per_type_counts[etype] += 1
        unique_id += 1

        ds = _dataset_from_group(ev["group"])

        date_str = ev["start_time"].strftime("%Y%m%d")
        fname = f"{alr_serial}_{date_str}_{unique_id:04d}_{seg_id_for_file:04d}_{etype}{per_type_counts[etype]:04d}.nc"
        fpath = os.path.join(output_dir, fname)

        ds.attrs.update({
            "alr_serial": alr_serial,
            "unique_id": unique_id,
            "segment_id": seg_id_for_file,
            "event_type": etype,         # d/u/t/s/x
            "group_kind": ev["kind"],    # profile/transect/other
            "group_key": ev["key"],
            "surface_threshold_m": surface_thresh,
            "event_start_utc": ev["start_time"].isoformat(),
        })

        ds.to_netcdf(fpath, engine="netcdf4", format="NETCDF4")
        written.append(fpath)

    return written

# -----------------------------

files = export_alr_netcdf(
    big_df_with_profiles,
    alr_serial="ALR005",
    surface_thresh=5.0,
    output_dir="output_ALR005_TechOceans_netCDF",
    max_files=None,   # set to None to export all
)
print("\n".join(files))
# Out:
# C:\Users\hanshil\AppData\Local\Temp\ipykernel_39532\1910196344.py:169: DeprecationWarning: `DataFrame.with_row_count` is deprecated; use `with_row_index` instead. Note that the default column name has changed from 'row_nr' to 'index'.
#   .with_row_count("orig_idx")
# C:\Users\hanshil\AppData\Local\Temp\ipykernel_39532\1910196344.py:218: DeprecationWarning: `DataFrame.with_row_count` is deprecated; use `with_row_index` instead. Note that the default column name has changed from 'row_nr' to 'index'.
#   seg_df = pl.DataFrame({"SEG_START": seg_starts}).with_row_count("segment_id", offset=1)
# output_ALR005_TechOceans_netCDF\ALR005_20240309_0001_0000_x0001.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240309_0002_0001_d0001.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240309_0003_0001_x0002.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240309_0004_0001_u0001.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240309_0005_0001_x0003.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240309_0006_0001_s0001.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240309_0007_0002_d0002.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240309_0008_0002_x0004.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240309_0009_0002_t0001.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240309_0010_0002_u0002.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240309_0011_0002_x0005.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240309_0012_0002_s0002.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0013_0003_d0003.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0014_0003_x0006.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0015_0003_t0002.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0016_0003_u0003.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0017_0003_x0007.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0018_0003_s0003.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0019_0004_d0004.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0020_0004_x0008.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0021_0004_t0003.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0022_0004_d0005.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0023_0004_x0009.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0024_0004_t0004.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0025_0004_d0006.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0026_0004_x0010.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0027_0004_t0005.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0028_0004_d0007.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0029_0004_x0011.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0030_0004_t0006.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0031_0004_d0008.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0032_0004_x0012.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0033_0004_t0007.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240311_0034_0004_u0004.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0035_0004_x0013.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0036_0004_s0004.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0037_0005_d0009.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0038_0005_x0014.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0039_0005_u0005.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0040_0005_x0015.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0041_0005_d0010.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0042_0005_x0016.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0043_0005_u0006.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0044_0005_x0017.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0045_0005_u0007.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0046_0005_x0018.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0047_0005_s0005.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0048_0006_d0011.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0049_0006_x0019.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0050_0006_t0008.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0051_0006_u0008.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0052_0006_x0020.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0053_0006_s0006.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0054_0007_d0012.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0055_0007_x0021.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0056_0007_t0009.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0057_0007_u0009.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0058_0007_x0022.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0059_0007_s0007.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0060_0008_d0013.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0061_0008_x0023.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0062_0008_t0010.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0063_0008_u0010.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0064_0008_x0024.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0065_0008_s0008.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0066_0009_d0014.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0067_0009_x0025.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0068_0009_u0011.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0069_0009_x0026.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0070_0009_s0009.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0071_0010_d0015.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0072_0010_x0027.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0073_0010_t0011.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0074_0010_u0012.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0075_0010_x0028.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240312_0076_0010_s0010.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240315_0077_0011_d0016.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240315_0078_0011_x0029.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240315_0079_0011_t0012.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240315_0080_0011_u0013.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240315_0081_0011_x0030.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240315_0082_0011_t0013.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240315_0083_0011_u0014.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240315_0084_0011_s0011.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240315_0085_0012_d0017.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240315_0086_0012_x0031.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240315_0087_0012_t0014.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240315_0088_0012_u0015.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240315_0089_0012_x0032.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240315_0090_0012_s0012.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0091_0013_d0018.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0092_0013_x0033.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0093_0013_t0015.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0094_0013_u0016.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0095_0013_x0034.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0096_0013_s0013.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0097_0014_d0019.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0098_0014_x0035.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0099_0014_d0020.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0100_0014_x0036.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0101_0014_t0016.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0102_0014_u0017.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0103_0014_x0037.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0104_0014_s0014.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0105_0015_d0021.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0106_0015_x0038.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0107_0015_t0017.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0108_0015_d0022.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0109_0015_x0039.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0110_0015_u0018.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0111_0015_x0040.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0112_0015_d0023.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0113_0015_x0041.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0114_0015_u0019.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0115_0015_x0042.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0116_0015_u0020.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0117_0015_x0043.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0118_0015_s0015.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0119_0016_d0024.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0120_0016_x0044.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0121_0016_u0021.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0122_0016_x0045.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0123_0016_t0018.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0124_0016_u0022.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0125_0016_x0046.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0126_0016_s0016.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0127_0017_d0025.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0128_0017_x0047.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0129_0017_t0019.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0130_0017_d0026.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0131_0017_x0048.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0132_0017_u0023.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0133_0017_x0049.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0134_0017_d0027.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0135_0017_x0050.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0136_0017_u0024.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0137_0017_x0051.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0138_0017_s0017.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0139_0018_d0028.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0140_0018_x0052.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240316_0141_0018_t0020.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0142_0018_d0029.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0143_0018_x0053.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0144_0018_u0025.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0145_0018_x0054.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0146_0018_d0030.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0147_0018_x0055.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0148_0018_u0026.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0149_0018_x0056.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0150_0018_t0021.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0151_0018_u0027.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0152_0018_x0057.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0153_0018_s0018.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0154_0019_d0031.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0155_0019_x0058.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0156_0019_t0022.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0157_0019_d0032.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0158_0019_x0059.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0159_0019_u0028.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0160_0019_x0060.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0161_0019_d0033.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0162_0019_x0061.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0163_0019_u0029.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0164_0019_x0062.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0165_0019_d0034.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0166_0019_x0063.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0167_0019_u0030.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0168_0019_x0064.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0169_0019_d0035.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0170_0019_x0065.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0171_0019_t0023.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0172_0019_u0031.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0173_0019_x0066.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0174_0019_s0019.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0175_0020_d0036.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0176_0020_x0067.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0177_0020_u0032.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0178_0020_x0068.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0179_0020_u0033.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0180_0020_x0069.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0181_0020_s0020.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0182_0021_d0037.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0183_0021_x0070.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0184_0021_t0024.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0185_0021_u0034.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0186_0021_x0071.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0187_0021_t0025.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0188_0021_u0035.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0189_0021_x0072.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0190_0021_s0021.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0191_0022_d0038.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0192_0022_x0073.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0193_0022_t0026.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0194_0022_u0036.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0195_0022_x0074.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0196_0022_t0027.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240317_0197_0022_u0037.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0198_0022_x0075.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0199_0022_s0022.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0200_0023_d0039.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0201_0023_x0076.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0202_0023_t0028.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0203_0023_u0038.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0204_0023_x0077.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0205_0023_t0029.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0206_0023_u0039.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0207_0023_x0078.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0208_0023_s0023.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0209_0024_d0040.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0210_0024_x0079.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0211_0024_t0030.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0212_0024_u0040.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0213_0024_x0080.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0214_0024_t0031.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0215_0024_u0041.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0216_0024_x0081.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0217_0024_s0024.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0218_0025_d0041.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0219_0025_x0082.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0220_0025_u0042.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0221_0025_x0083.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0222_0025_s0025.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0223_0026_d0042.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0224_0026_x0084.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0225_0026_t0032.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0226_0026_u0043.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0227_0026_x0085.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0228_0026_t0033.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0229_0026_u0044.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0230_0026_x0086.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0231_0026_s0026.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0232_0027_d0043.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0233_0027_x0087.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0234_0027_t0034.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0235_0027_u0045.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0236_0027_x0088.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0237_0027_t0035.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0238_0027_u0046.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0239_0027_x0089.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0240_0027_s0027.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0241_0028_d0044.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0242_0028_x0090.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0243_0028_t0036.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0244_0028_u0047.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0245_0028_x0091.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240318_0246_0028_t0037.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0247_0028_u0048.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0248_0028_x0092.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0249_0028_s0028.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0250_0029_d0045.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0251_0029_x0093.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0252_0029_t0038.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0253_0029_u0049.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0254_0029_x0094.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0255_0029_t0039.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0256_0029_u0050.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0257_0029_x0095.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0258_0029_s0029.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0259_0030_d0046.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0260_0030_x0096.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0261_0030_u0051.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0262_0030_x0097.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0263_0030_u0052.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0264_0030_x0098.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0265_0030_s0030.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0266_0031_d0047.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0267_0031_x0099.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0268_0031_t0040.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0269_0031_u0053.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0270_0031_x0100.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0271_0031_t0041.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0272_0031_u0054.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0273_0031_x0101.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0274_0031_s0031.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0275_0032_d0048.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0276_0032_x0102.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0277_0032_t0042.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0278_0032_u0055.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0279_0032_x0103.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0280_0032_t0043.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0281_0032_u0056.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240319_0282_0032_x0104.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0283_0032_s0032.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0284_0033_d0049.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0285_0033_x0105.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0286_0033_t0044.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0287_0033_u0057.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0288_0033_x0106.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0289_0033_t0045.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0290_0033_u0058.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0291_0033_x0107.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0292_0033_s0033.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0293_0034_d0050.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0294_0034_x0108.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0295_0034_t0046.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0296_0034_u0059.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0297_0034_x0109.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0298_0034_t0047.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0299_0034_u0060.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0300_0034_x0110.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0301_0034_s0034.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0302_0035_d0051.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0303_0035_x0111.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0304_0035_u0061.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0305_0035_x0112.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0306_0035_u0062.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0307_0035_x0113.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0308_0035_s0035.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0309_0036_d0052.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0310_0036_x0114.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0311_0036_t0048.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0312_0036_u0063.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0313_0036_x0115.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0314_0036_s0036.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0315_0037_d0053.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0316_0037_x0116.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0317_0037_t0049.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0318_0037_d0054.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0319_0037_x0117.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0320_0037_t0050.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0321_0037_d0055.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0322_0037_x0118.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0323_0037_t0051.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0324_0037_u0064.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0325_0037_x0119.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0326_0037_s0037.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0327_0038_d0056.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0328_0038_x0120.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0329_0038_d0057.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0330_0038_x0121.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0331_0038_t0052.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0332_0038_d0058.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0333_0038_x0122.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0334_0038_t0053.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0335_0038_d0059.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0336_0038_x0123.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0337_0038_t0054.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0338_0038_u0065.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0339_0038_x0124.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0340_0038_s0038.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0341_0039_d0060.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0342_0039_x0125.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0343_0039_u0066.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0344_0039_x0126.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240320_0345_0039_t0055.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0346_0039_u0067.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0347_0039_x0127.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0348_0039_t0056.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0349_0039_u0068.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0350_0039_x0128.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0351_0039_t0057.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0352_0039_u0069.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0353_0039_x0129.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0354_0039_s0039.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0355_0040_d0061.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0356_0040_x0130.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0357_0040_t0058.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0358_0040_u0070.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0359_0040_x0131.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0360_0040_s0040.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0361_0041_d0062.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0362_0041_x0132.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0363_0041_t0059.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0364_0041_u0071.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0365_0041_x0133.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0366_0041_s0041.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0367_0042_d0063.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0368_0042_x0134.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0369_0042_t0060.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0370_0042_u0072.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0371_0042_x0135.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0372_0042_s0042.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0373_0043_d0064.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0374_0043_x0136.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0375_0043_t0061.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0376_0043_u0073.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0377_0043_x0137.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0378_0043_s0043.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0379_0044_d0065.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0380_0044_x0138.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0381_0044_t0062.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0382_0044_u0074.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0383_0044_x0139.nc
# output_ALR005_TechOceans_netCDF\ALR005_20240321_0384_0044_s0044.nc
